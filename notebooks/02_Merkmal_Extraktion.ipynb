# %%
import pandas as pd

# %% [markdown]
# ### Daten aus pickle Dateien laden

# %%
df = pd.read_pickle("instagram_node_dataframe.pkl")
df

# %%
df.columns

# %% [markdown]
# ### Datenbereinigung
# - Entfernung unnötiger Spalten, die keine Bedeutung für die Arbeit hatten

# %%
df = df.drop(columns=['taken_at_timestamp', 'viewer_has_liked', 'viewer_has_saved', 'viewer_has_saved_to_collection', 'viewer_in_photo_of_you', 'viewer_can_reshare', 'has_upcoming_event', 'coauthor_producers', 'pinned_for_users', 'comments_disabled', 'is_video', 'owner.is_guardian_of_viewer', 'owner.is_supervision_enabled', 'owner.is_supervised_by_viewer', 'owner.is_supervised_user', 'owner.is_embeds_disabled', 'owner.is_joined_recently', 'owner.business_contact_method', 'owner.edge_mutual_followed_by.count', 'owner.is_private', 'owner.edge_mutual_followed_by.edges', 'owner.requested_by_viewer', 'owner.pronouns'])
df
